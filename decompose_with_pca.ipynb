# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('temp.npy')
data.shape
# Out:
# (501, 4, 16, 32, 32)

# %%
data = data[:,0,-1,:,:]

# %%
data.shape
# Out:
# (501, 32, 32)

# %%
data = data.reshape(501,-1)
data.shape
# Out:
# (501, 1024)

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(data)
# Out:
# PCA()

# %%
plt.plot(pca.explained_variance_ratio_,'-o')
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %%
print(pca.explained_variance_ratio_[:10].sum())
# Out:
# 0.9742332045604378

# %%
decomposed_data = pca.transform(data)[:,:10]

# %%
decomposed_data.shape
# Out:
# (501, 10)

# %% [markdown]
# * CASE 1 : BHP assimilation via ES-MDA
# * CASE 2 : BHP + Insar, pure concatenation
# * CASE 3 : BHP + InsarWithPCA, upto 10 PCs
# * (advanced) CASE 4 : BHP + InsarWithPCA + elevation on well locations
#
# ---
# * (future) : BHP + "AE" applied Insar
